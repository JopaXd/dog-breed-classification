# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import argparse
import pickle
import h5py

# %%
# open the HDF5 database for reading then determine the index of
# the training and testing split, provided that this data was
# already shuffled *prior* to writing it to disk
db = h5py.File("/media/pavle/HDD_disk/deep-learning/dog-breed-dataset/features.hdf5")
i = int(db["labels"].shape[0] * 0.75)

# %%
print("[INFO] tuning hyperparameters...")
params = {"C": [0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0]}
model = GridSearchCV(LogisticRegression(), params, cv=3, n_jobs=-1, pre_dispatch=6)
model.fit(db["features"][:i], db["labels"][:i])
# Out:
# [INFO] tuning hyperparameters...
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/pavle/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0]},
#              pre_dispatch=6)

# %%
print("[INFO] best hyperparameters: {}".format(model.best_params_))
# Out:
# [INFO] best hyperparameters: {'C': 0.1}

# %%
# evaluate the model
print("[INFO] evaluating...")
preds = model.predict(db["features"][i:])
print("[INFO] Done!")
# Out:
# [INFO] evaluating...
# [INFO] Done!

# %%
print(db["labels"][i:])
print(db["label_names"])
print(classification_report(db["labels"][i:], preds, target_names=[str(x, "utf-8") for x in db["label_names"]]))
# Out:
# [113  94  18 ...  57  75  98]
# <HDF5 dataset "label_names": shape (120,), type "|O">
#                                 precision    recall  f1-score   support
#
#                   Afghan_hound       0.87      0.74      0.80        78
#            African_hunting_dog       0.90      0.90      0.90        39
#                       Airedale       0.76      0.67      0.71        52
# American_Staffordshire_terrier       0.42      0.33      0.37        39
#                    Appenzeller       0.31      0.24      0.27        41
#             Australian_terrier       0.56      0.60      0.58        55
#             Bedlington_terrier       0.94      0.92      0.93        50
#           Bernese_mountain_dog       0.79      0.69      0.74        49
#               Blenheim_spaniel       0.83      0.94      0.88        47
#                  Border_collie       0.53      0.63      0.58        38
#                 Border_terrier       0.75      0.79      0.77        34
#                    Boston_bull       0.62      0.78      0.69        49
#           Bouvier_des_Flandres       0.62      0.63      0.62        38
#              Brabancon_griffon       0.76      0.95      0.84        37
#               Brittany_spaniel       0.69      0.80      0.74        41
#                       Cardigan       0.45      0.52      0.48        25
#       Chesapeake_Bay_retriever       0.62      0.65      0.63        48
#                      Chihuahua       0.41      0.69      0.51        26
#                 Dandie_Dinmont       0.90      0.65      0.76        57
#                       Doberman       0.68      0.64      0.66        39
#               English_foxhound       0.50      0.54      0.52        37
#                 English_setter       0.63      0.76      0.69        34
#               English_springer       0.68      0.64      0.66        44
#                    EntleBucher       0.63      0.75      0.69        57
#                     Eskimo_dog       0.41      0.38      0.39        40
#                 French_bulldog       0.64      0.53      0.58        40
#                German_shepherd       0.82      0.71      0.76        38
#                   German_short       0.86      0.78      0.82        40
#                  Gordon_setter       0.90      0.95      0.92        37
#                     Great_Dane       0.59      0.50      0.54        44
#                 Great_Pyrenees       0.62      0.58      0.60        50
#     Greater_Swiss_Mountain_dog       0.55      0.62      0.58        34
#                   Ibizan_hound       0.93      0.79      0.85        48
#                   Irish_setter       0.78      0.91      0.84        32
#                  Irish_terrier       0.69      0.72      0.71        50
#            Irish_water_spaniel       0.79      0.84      0.82        37
#                Irish_wolfhound       0.53      0.53      0.53        51
#              Italian_greyhound       0.72      0.55      0.63        56
#               Japanese_spaniel       0.96      0.88      0.92        52
#             Kerry_blue_terrier       0.72      0.89      0.80        44
#             Labrador_retriever       0.49      0.46      0.47        48
#               Lakeland_terrier       0.45      0.73      0.56        37
#                       Leonberg       0.75      0.80      0.77        54
#                          Lhasa       0.54      0.58      0.56        48
#                    Maltese_dog       0.76      0.81      0.78        62
#               Mexican_hairless       0.91      0.83      0.87        47
#                   Newfoundland       0.51      0.51      0.51        45
#                Norfolk_terrier       0.51      0.62      0.56        47
#             Norwegian_elkhound       0.87      0.85      0.86        47
#                Norwich_terrier       0.50      0.44      0.47        45
#           Old_English_sheepdog       0.87      0.74      0.80        54
#                       Pekinese       0.58      0.55      0.57        38
#                       Pembroke       0.82      0.76      0.78        41
#                     Pomeranian       0.84      0.86      0.85        50
#            Rhodesian_ridgeback       0.56      0.50      0.53        40
#                     Rottweiler       0.75      0.81      0.78        37
#                  Saint_Bernard       0.78      0.88      0.83        43
#                         Saluki       0.66      0.67      0.67        46
#                        Samoyed       0.80      0.90      0.84        48
#                 Scotch_terrier       0.84      0.75      0.79        36
#             Scottish_deerhound       0.77      0.74      0.75        68
#               Sealyham_terrier       0.70      0.96      0.81        55
#              Shetland_sheepdog       0.58      0.63      0.60        35
#                           Shih       0.60      0.60      0.60        55
#                 Siberian_husky       0.53      0.36      0.42        59
#      Staffordshire_bullterrier       0.53      0.53      0.53        40
#                 Sussex_spaniel       0.89      0.83      0.86        41
#                Tibetan_mastiff       0.57      0.75      0.65        28
#                Tibetan_terrier       0.74      0.67      0.70        58
#                   Walker_hound       0.38      0.38      0.38        39
#                     Weimaraner       0.79      0.68      0.73        40
#         Welsh_springer_spaniel       0.66      0.64      0.65        39
#    West_Highland_white_terrier       0.74      0.66      0.70        44
#              Yorkshire_terrier       0.51      0.60      0.55        40
#                  affenpinscher       0.76      0.67      0.71        39
#                        basenji       0.70      0.85      0.76        46
#                         basset       0.83      0.71      0.77        42
#                         beagle       0.47      0.44      0.46        43
#                          black       0.70      0.78      0.74        41
#                     bloodhound       0.76      0.76      0.76        46
#                       bluetick       0.73      0.80      0.76        44
#                         borzoi       0.71      0.59      0.65        34
#                          boxer       0.70      0.58      0.63        33
#                         briard       0.58      0.59      0.58        32
#                   bull_mastiff       0.78      0.74      0.76        43
#                          cairn       0.64      0.70      0.67        53
#                           chow       1.00      0.82      0.90        45
#                        clumber       0.86      0.81      0.83        31
#                 cocker_spaniel       0.72      0.63      0.67        46
#                         collie       0.54      0.38      0.44        37
#                          curly       0.89      0.82      0.85        49
#                          dhole       0.84      0.94      0.89        33
#                          dingo       0.61      0.78      0.68        36
#                           flat       0.62      0.69      0.66        29
#                giant_schnauzer       0.61      0.66      0.63        38
#               golden_retriever       0.61      0.69      0.65        39
#                    groenendael       0.79      0.73      0.76        37
#                       keeshond       0.97      0.89      0.93        37
#                         kelpie       0.57      0.50      0.53        42
#                       komondor       0.74      0.74      0.74        31
#                         kuvasz       0.67      0.59      0.62        34
#                       malamute       0.53      0.60      0.57        43
#                       malinois       0.80      0.77      0.79        31
#             miniature_pinscher       0.61      0.65      0.63        48
#               miniature_poodle       0.52      0.31      0.39        48
#            miniature_schnauzer       0.57      0.63      0.60        38
#                     otterhound       0.73      0.69      0.71        39
#                       papillon       0.91      0.89      0.90        44
#                            pug       0.83      0.80      0.82        61
#                        redbone       0.58      0.56      0.57        39
#                     schipperke       0.77      0.73      0.75        37
#                  silky_terrier       0.59      0.57      0.58        51
#                           soft       0.63      0.51      0.57        37
#                standard_poodle       0.56      0.56      0.56        39
#             standard_schnauzer       0.62      0.52      0.57        48
#                     toy_poodle       0.26      0.43      0.33        23
#                    toy_terrier       0.70      0.60      0.65        53
#                         vizsla       0.70      0.81      0.75        37
#                        whippet       0.25      0.41      0.31        32
#                           wire       0.72      0.58      0.65        36
#
#                       accuracy                           0.68      5145
#                      macro avg       0.68      0.68      0.67      5145
#                   weighted avg       0.69      0.68      0.68      5145

# %%
# serialize the model to disk
print("[INFO] saving model...")
f = open("model.hdf5", "wb")
f.write(pickle.dumps(model.best_estimator_))
f.close()
# close the database
db.close()
# Out:
# [INFO] saving model...
